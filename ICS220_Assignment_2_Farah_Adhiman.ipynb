# %% [markdown]
# # Part B:

# %%
class Guest:

    # Initializing the attributes for the Guest class (private)
    def __init__(self, nameofguest, emailguest, guestphonenumber, guestid, guestloyalty):
        self.__nameofguest = nameofguest
        self.__emailguest = emailguest
        self.__guestphonenumber = guestphonenumber
        self.__guestid = guestid
        self.__guestloyalty = guestloyalty

    # Getter methods
    def get_nameofguest(self):
        return self.__nameofguest

    def get_emailguest(self):
        return self.__emailguest

    def get_guestphonenumber(self):
        return self.__guestphonenumber

    def get_guestid(self):
        return self.__guestid

    def get_guestloyalty(self):
        return self.__guestloyalty

    # Setter methods
    def set_nameofguest(self, nameofguest):
        self.__nameofguest = nameofguest

    def set_emailguest(self, emailguest):
        self.__emailguest = emailguest

    def set_guestphonenumber(self, guestphonenumber):
        self.__guestphonenumber = guestphonenumber

    def set_guestloyalty(self, guestloyalty):
        self.__guestloyalty = guestloyalty

    # Guest actions
    def guestcreateaccount(self):
        return "The guest account for", self.__nameofguest, "has been created!"

    def updateguestprofile(self):
        return "The guest profile for guest ID:", self.__guestid, "has been updated."

    def guestreservation(self):
        return "Displaying reservation history for guest with ID:", self.__guestid, "."

    # String representation
    def __str__(self):
        return f"Guest ID: {self.__guestid} - Name: {self.__nameofguest} - Email: {self.__emailguest} - Phone: {self.__guestphonenumber} - Loyalty: {self.__guestloyalty}"


class Booking:

    # Initializing the attributes for the Booking class (private)
    def __init__(self, guestid, roomnum, room_booking_id, statusofbooking, dateofcheckin, dateofcheckout):
        self.__guestid = guestid
        self.__roomnum = roomnum
        self.__room_booking_id = room_booking_id
        self.__statusofbooking = statusofbooking
        self.__dateofcheckin = dateofcheckin
        self.__dateofcheckout = dateofcheckout

    # Getter methods
    def get_guestid(self):
        return self.__guestid

    def get_roomnum(self):
        return self.__roomnum

    def get_room_booking_id(self):
        return self.__room_booking_id

    def get_statusofbooking(self):
        return self.__statusofbooking

    def get_dateofcheckin(self):
        return self.__dateofcheckin

    def get_dateofcheckout(self):
        return self.__dateofcheckout

    # Setter method
    def set_statusofbooking(self, status):
        self.__statusofbooking = status

    # Guest actions
    def checkavailability(self):
        return "Searching for rooms that are available..."

    def makereservation(self):
        return "Booking for guest with ID:", self.__guestid, "in room", self.__roomnum, "has been made."

    def confirming(self):
        return "Booking confirmation has been sent to guest owners of room:", self.__roomnum, "via Email."

    def cancel_reservation(self):
        self.set_statusofbooking("Cancelled")
        return "Booking with ID:", self.__room_booking_id, "has been cancelled."

    # String representation
    def __str__(self):
        return f"Booking ID: {self.__room_booking_id} - Guest ID: {self.__guestid} - Guest room: {self.__roomnum} - Booking status: {self.__statusofbooking} - Guest check-in: {self.__dateofcheckin} - Guest check-out: {self.__dateofcheckout}"

class Payment:

    # Initializing the attributes for the Payment class (private)
    def __init__(self, invoiceid, payment_id, methodofpayment, total, statusofpayment):
        self.__invoiceid = invoiceid
        self.__payment_id = payment_id
        self.__methodofpayment = methodofpayment
        self.__total = total
        self.__statusofpayment = statusofpayment

    # Getter methods
    def get_invoiceid(self):
        return self.__invoiceid

    def get_payment_id(self):
        return self.__payment_id

    def get_methodofpayment(self):
        return self.__methodofpayment

    def get_total(self):
        return self.__total

    def get_statusofpayment(self):
        return self.__statusofpayment

    # Setter method
    def set_statusofpayment(self, status):
        self.__statusofpayment = status

    # Guest actions
    def checkpaymentstatus(self):
        return "Payment status for payment with ID", self.__payment_id, "is", self.__statusofpayment, "."

    def processofpayment(self):
        return "Processing payment with ID", self.__payment_id, "using", self.__methodofpayment, "."

    # String representation
    def __str__(self):
        return f"Payment ID: {self.__payment_id} - Invoice ID: {self.__invoiceid} - Total payment amount: {self.__total} - Payment status: {self.__statusofpayment}"

class LoyaltyProgram:

    # Initializing the attributes for the LoyaltyProgram class (private)
    def __init__(self, guestid, loyaltypoints, rewardsstatus, requesttype):
        self.__guestid = guestid
        self.__loyaltypoints = loyaltypoints
        self.__rewardsstatus = rewardsstatus
        self.__requesttype = requesttype

    # Getter methods
    def get_guestid(self):
        return self.__guestid

    def get_loyaltypoints(self):
        return self.__loyaltypoints

    def get_rewardsstatus(self):
        return self.__rewardsstatus

    def get_requesttype(self):
        return self.__requesttype

    # Setter methods
    def set_loyaltypoints(self, points):
        self.__loyaltypoints = points

    def set_rewardsstatus(self, status):
        self.__rewardsstatus = status

    def set_requesttype(self, requesttype):
        self.__requesttype = requesttype

    # Guest actions
    def checkrewards_and_status(self):
        return "Guest", self.__guestid, "has", self.__loyaltypoints, "points and reward status is", self.__rewardsstatus, "."

    def redeem(self):
        return "Redeeming loyalty rewards for guest", self.__guestid, "."

    def addmorepoints(self):
        return "Loyalty points have been added for guest with ID:", self.__guestid, "."

    # String representation
    def __str__(self):
        return f"Guest ID: {self.__guestid} - Loyalty points: {self.__loyaltypoints} - Reward status: {self.__rewardsstatus} - Request type: {self.__requesttype}"

class GuestService:

    # Initializing the attributes for the GuestService class (private)
    def __init__(self, guestid, requestid, statusofrequest, requesttype):
        self.__guestid = guestid
        self.__requestid = requestid
        self.__statusofrequest = statusofrequest
        self.__requesttype = requesttype

    # Getter methods
    def get_guestid(self):
        return self.__guestid

    def get_requestid(self):
        return self.__requestid

    def get_statusofrequest(self):
        return self.__statusofrequest

    def get_requesttype(self):
        return self.__requesttype

    # Setter method
    def set_statusofrequest(self, status):
        self.__statusofrequest = status

    # Guest actions
    def sendservice(self):
        return "Request with ID:", self.__requestid, "has been sent by guest with ID:", self.__guestid, "."

    def informstaff(self):
        return "Hotel staff have been notified for request with ID:", self.__requestid, "."

    # String representation
    def __str__(self):
        return f"Request ID: {self.__requestid} - Guest ID: {self.__guestid} - Request type: {self.__requesttype} - Request status: {self.__statusofrequest}"

class Feedback:

    # Initializing the attributes for the Feedback class (private)
    def __init__(self, guestid, feedbackid, comment, rating):
        self.__guestid = guestid
        self.__feedbackid = feedbackid
        self.__comment = comment
        self.__rating = rating

    # Getter methods
    def get_guestid(self):
        return self.__guestid

    def get_feedbackid(self):
        return self.__feedbackid

    def get_comment(self):
        return self.__comment

    def get_rating(self):
        return self.__rating

    # Setter methods
    def set_comment(self, comment):
        self.__comment = comment

    def set_rating(self, rating):
        self.__rating = rating

    # Guest action
    def submitting(self):
        return "Feedback has been submitted by guest with ID:", self.__guestid, "."

    # String representation
    def __str__(self):
        return f"Feedback ID: {self.__feedbackid} - Guest ID: {self.__guestid} - Guest rating: {self.__rating} - Guest comment: {self.__comment}"

# %% [markdown]
# # Part C:

# %%
class Guest:

    # Initializing the attributes for the Guest class (private)
    def __init__(self, nameofguest, emailguest, guestphonenumber, guestid, guestloyalty):
        self.__nameofguest = nameofguest
        self.__emailguest = emailguest
        self.__guestphonenumber = guestphonenumber
        self.__guestid = guestid
        self.__guestloyalty = guestloyalty

    # Getter methods
    def get_nameofguest(self):
        return self.__nameofguest

    def get_emailguest(self):
        return self.__emailguest

    def get_guestphonenumber(self):
        return self.__guestphonenumber

    def get_guestid(self):
        return self.__guestid

    def get_guestloyalty(self):
        return self.__guestloyalty

    # Setter methods
    def set_nameofguest(self, nameofguest):
        self.__nameofguest = nameofguest

    def set_emailguest(self, emailguest):
        self.__emailguest = emailguest

    def set_guestphonenumber(self, guestphonenumber):
        self.__guestphonenumber = guestphonenumber

    def set_guestloyalty(self, guestloyalty):
        self.__guestloyalty = guestloyalty

    # Guest actions
    def guestcreateaccount(self):
        return "The guest account for", self.__nameofguest, "has been created!"

    def updateguestprofile(self):
        return "The guest profile for guest ID:", self.__guestid, "has been updated."

    def guestreservation(self):
        return "Displaying reservation history for guest with ID:", self.__guestid, "."

    # String representation
    def __str__(self):
        return f"Guest ID: {self.__guestid} - Name: {self.__nameofguest} - Email: {self.__emailguest} - Phone: {self.__guestphonenumber} - Loyalty: {self.__guestloyalty}"

# Test Case: Guest Account Creation

# Creating two guest accounts with name, email, phone, ID, and loyalty status
guest1 = Guest("Reem Mutaeb", "reem@gmail.com", "0501234567", "G132", "Loyal-2")
guest2 = Guest("Rama Ali", "rama@gmail.com", "0555521022", "G227", "Loyal-3")

# Confirming account creation
print(guest1.guestcreateaccount())
print(guest1)

print("---")

print(guest2.guestcreateaccount())
print(guest2)
# Out:
# ('The guest account for', 'Reem Mutaeb', 'has been created!')
# Guest ID: G132 - Name: Reem Mutaeb - Email: reem@gmail.com - Phone: 0501234567 - Loyalty: Loyal-2
# ---
# ('The guest account for', 'Rama Ali', 'has been created!')
# Guest ID: G227 - Name: Rama Ali - Email: rama@gmail.com - Phone: 0555521022 - Loyalty: Loyal-3

# %%
class Payment:

    # Initializing the attributes for the Payment class (private)
    def __init__(self, invoiceid, payment_id, methodofpayment, total, statusofpayment):
        self.__invoiceid = invoiceid
        self.__payment_id = payment_id
        self.__methodofpayment = methodofpayment
        self.__total = total
        self.__statusofpayment = statusofpayment

    # Getter methods
    def get_invoiceid(self):
        return self.__invoiceid

    def get_payment_id(self):
        return self.__payment_id

    def get_methodofpayment(self):
        return self.__methodofpayment

    def get_total(self):
        return self.__total

    def get_statusofpayment(self):
        return self.__statusofpayment

    # Setter method
    def set_statusofpayment(self, status):
        self.__statusofpayment = status

    # Guest actions
    def checkpaymentstatus(self):
        return "Payment status for payment with ID", self.__payment_id, "is", self.__statusofpayment, "."

    def processofpayment(self):
        return "Processing payment with ID", self.__payment_id, "using", self.__methodofpayment, "."

    # String representation
    def __str__(self):
        return f"Payment ID: {self.__payment_id} - Invoice ID: {self.__invoiceid} - Total payment amount: {self.__total} - Payment status: {self.__statusofpayment}"

# Test Case: Payment processing and status check

# Create two Payment objects
payment1 = Payment("INV001", "P001", "Credit Card", "1200", "Pending")
payment2 = Payment("INV002", "P002", "Mobile Wallet", "900", "Completed")

# Test processofpayment() method
print(payment1.processofpayment())
print(payment2.processofpayment())
print("---")

# Test checkpaymentstatus() method
print(payment1.checkpaymentstatus())
print(payment2.checkpaymentstatus())
print("---")

# Print full payment details using __str__()
print(payment1)
print(payment2)
print("---")
# Out:
# ('Processing payment with ID', 'P001', 'using', 'Credit Card', '.')
# ('Processing payment with ID', 'P002', 'using', 'Mobile Wallet', '.')
# ---
# ('Payment status for payment with ID', 'P001', 'is', 'Pending', '.')
# ('Payment status for payment with ID', 'P002', 'is', 'Completed', '.')
# ---
# Payment ID: P001 - Invoice ID: INV001 - Total payment amount: 1200 - Payment status: Pending
# Payment ID: P002 - Invoice ID: INV002 - Total payment amount: 900 - Payment status: Completed
# ---

# %%
class LoyaltyProgram:

    # Initializing the attributes for the LoyaltyProgram class (private)
    def __init__(self, guestid, loyaltypoints, rewardsstatus, requesttype):
        self.__guestid = guestid
        self.__loyaltypoints = loyaltypoints
        self.__rewardsstatus = rewardsstatus
        self.__requesttype = requesttype

    # Getter methods
    def get_guestid(self):
        return self.__guestid

    def get_loyaltypoints(self):
        return self.__loyaltypoints

    def get_rewardsstatus(self):
        return self.__rewardsstatus

    def get_requesttype(self):
        return self.__requesttype

    # Setter methods
    def set_loyaltypoints(self, points):
        self.__loyaltypoints = points

    def set_rewardsstatus(self, status):
        self.__rewardsstatus = status

    def set_requesttype(self, requesttype):
        self.__requesttype = requesttype

    # Guest actions
    def checkrewards_and_status(self):
        return "Guest", self.__guestid, "has", self.__loyaltypoints, "points and reward status is", self.__rewardsstatus, "."

    def redeem(self):
        return "Redeeming loyalty rewards for guest", self.__guestid, "."

    def addmorepoints(self):
        return "Loyalty points have been added for guest with ID:", self.__guestid, "."

    # String representation
    def __str__(self):
        return f"Guest ID: {self.__guestid} - Loyalty points: {self.__loyaltypoints} - Reward status: {self.__rewardsstatus} - Request type: {self.__requesttype}"

# Test Case: Loyalty program features

# Create two LoyaltyProgram objects
loyalty1 = LoyaltyProgram("G132", 200, "Eligible", "Add Points")
loyalty2 = LoyaltyProgram("G227", 80, "Not Eligible", "Check Status")
print("---")

# Test checkrewards_and_status() method
print(loyalty1.checkrewards_and_status())
print(loyalty2.checkrewards_and_status())
print("---")

# Test redeem() method
print(loyalty1.redeem())
print(loyalty2.redeem())
print("---")

# Test addmorepoints() method
print(loyalty1.addmorepoints())
print(loyalty2.addmorepoints())
print("---")

# Print full loyalty details using __str__()
print(loyalty1)
print(loyalty2)
# Out:
# ---
# ('Guest', 'G132', 'has', 200, 'points and reward status is', 'Eligible', '.')
# ('Guest', 'G227', 'has', 80, 'points and reward status is', 'Not Eligible', '.')
# ---
# ('Redeeming loyalty rewards for guest', 'G132', '.')
# ('Redeeming loyalty rewards for guest', 'G227', '.')
# ---
# ('Loyalty points have been added for guest with ID:', 'G132', '.')
# ('Loyalty points have been added for guest with ID:', 'G227', '.')
# ---
# Guest ID: G132 - Loyalty points: 200 - Reward status: Eligible - Request type: Add Points
# Guest ID: G227 - Loyalty points: 80 - Reward status: Not Eligible - Request type: Check Status

# %%
class GuestService:

    # Initializing the attributes for the GuestService class (private)
    def __init__(self, guestid, requestid, statusofrequest, requesttype):
        self.__guestid = guestid
        self.__requestid = requestid
        self.__statusofrequest = statusofrequest
        self.__requesttype = requesttype

    # Getter methods
    def get_guestid(self):
        return self.__guestid

    def get_requestid(self):
        return self.__requestid

    def get_statusofrequest(self):
        return self.__statusofrequest

    def get_requesttype(self):
        return self.__requesttype

    # Setter method
    def set_statusofrequest(self, status):
        self.__statusofrequest = status

    # Guest actions
    def sendservice(self):
        return "ID:", self.__requestid, "has been sent by guest with ID:", self.__guestid, "."

    def informstaff(self):
        return "Hotel staff have been notified for request with ID:", self.__requestid, "."

    # String representation
    def __str__(self):
        return f"Request ID: {self.__requestid} - Guest ID: {self.__guestid} - Request type: {self.__requesttype} - Request status: {self.__statusofrequest}"

# Test Case: Guest service requests

# Create two GuestService objects
service1 = GuestService("G132", "Service1", "Pending", "Room Cleaning")
service2 = GuestService("G227", "Service2", "In Progress", "Food Delivery")
print("---")

# Test sendservice() method
print(service1.sendservice())
print(service2.sendservice())
print("---")

# Test informstaff() method
print(service1.informstaff())
print(service2.informstaff())
print("---")

# Print full service request details using __str__()
print(service1)
print(service2)
# Out:
# ---
# ('ID:', 'Service1', 'has been sent by guest with ID:', 'G132', '.')
# ('ID:', 'Service2', 'has been sent by guest with ID:', 'G227', '.')
# ---
# ('Hotel staff have been notified for request with ID:', 'Service1', '.')
# ('Hotel staff have been notified for request with ID:', 'Service2', '.')
# ---
# Request ID: Service1 - Guest ID: G132 - Request type: Room Cleaning - Request status: Pending
# Request ID: Service2 - Guest ID: G227 - Request type: Food Delivery - Request status: In Progress

# %%
class Feedback:

    # Initializing the attributes for the Feedback class (private)
    def __init__(self, guestid, feedbackid, comment, rating):
        self.__guestid = guestid
        self.__feedbackid = feedbackid
        self.__comment = comment
        self.__rating = rating

    # Getter methods
    def get_guestid(self):
        return self.__guestid

    def get_feedbackid(self):
        return self.__feedbackid

    def get_comment(self):
        return self.__comment

    def get_rating(self):
        return self.__rating

    # Setter methods
    def set_comment(self, comment):
        self.__comment = comment

    def set_rating(self, rating):
        self.__rating = rating

    # Guest action
    def submitting(self):
        return "Feedback has been submitted by guest with ID:", self.__guestid, "."

    # String representation
    def __str__(self):
        return f"Feedback ID: {self.__feedbackid} - Guest ID: {self.__guestid} - Guest rating: {self.__rating} - Guest comment: {self.__comment}"

# Test Case: Guest feedback submissions

# Create two Feedback objects
feedback1 = Feedback("G132", "F007", "Amazing experience! Staff was super helpful.", 5)
feedback2 = Feedback("G227", "F008", "Room was clean but service was a bit slow.", 3)

# Test submitting() method
print(feedback1.submitting())
print(feedback2.submitting())
print("---")

# Print full feedback details using __str__()
print(feedback1)
print(feedback2)
print("---")
# Out:
# ('Feedback has been submitted by guest with ID:', 'G132', '.')
# ('Feedback has been submitted by guest with ID:', 'G227', '.')
# ---
# Feedback ID: F007 - Guest ID: G132 - Guest rating: 5 - Guest comment: Amazing experience! Staff was super helpful.
# Feedback ID: F008 - Guest ID: G227 - Guest rating: 3 - Guest comment: Room was clean but service was a bit slow.
# ---
